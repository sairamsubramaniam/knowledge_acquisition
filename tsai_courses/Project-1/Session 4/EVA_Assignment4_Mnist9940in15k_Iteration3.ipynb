# %% [markdown]
# ##Iteration 3 - Dropout (Reduce overfitting ) & Batch-normalization (Accentuate Weak Kernels)
#
# * In our previous model, we achieved a validation accuracy of 99.09 (most of the epochs this was less than 99.0), however the training accuracy was 99.53
#
# * This looks like a case of overe-fitting, since high training accuracy is not reflected in validation accuracy
#
# * We will try to rectify this situation using dropouts, starting with dropping out 20% of the kernels in each layer and increasing it upto 50, if we don't achieve our target
#
# * _Improved accuracy with dropout layers: 99.26_
#
# * _Accuracy with batch normalization layers added after dropouts: 99.30_
#
# ###HIGHEST ACCURACY ACHIEVED:  99.30

# %% [markdown]
# ### **Import Libraries and modules**

# %%
# https://keras.io/
# !pip install -q keras
import keras

import numpy as np

from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, Add, BatchNormalization
from keras.layers import Convolution2D, MaxPooling2D
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint

from keras.datasets import mnist
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Load pre-shuffled MNIST data & inspect a few images

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

print (X_train.shape)
from matplotlib import pyplot as plt
# %matplotlib inline
plt.imshow(X_train[0])
# Out:
# (60000, 28, 28)

# %% [markdown]
# ###Modify loaded data to match with the shape of form of an input required by a keras model

# %%
X_train = X_train.reshape(X_train.shape[0], 28, 28,1)
X_test = X_test.reshape(X_test.shape[0], 28, 28,1)

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Convert 1-dimensional class arrays to 10-dimensional class matrices
Y_train = np_utils.to_categorical(y_train, 10)
Y_test = np_utils.to_categorical(y_test, 10)

# %% [markdown]
# ###Build the network

# %%
from keras.layers import Activation
model = Sequential()

#Convolution Block 1
model.add(Convolution2D(8, 3, activation='relu', input_shape=(28,28,1)))     #Receptive Field:  3;   Input Channels:  3;  Resol:  26
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Convolution2D(8, 3, activation='relu'))                           #Receptive Field:  5;   Input Channels:  8;  Resol:  24
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Convolution2D(28, 3, activation='relu'))                           #Receptive Field:  7;   Input Channels: 8;  Resol:  22
model.add(BatchNormalization())
model.add(Dropout(0.2))

#Transition Block 1
model.add(Convolution2D(32, 1, activation='relu'))                           #Receptive Field:  7;   Input Channels: 28;  Resol:  22
model.add(MaxPooling2D(2,2))                                                    #Receptive Field: 14;   Input Channels: 32;  Resol:  11

#Convolution Block 2
model.add(Convolution2D(8, 3, activation='relu'))                            #Receptive Field: 16;   Input Channels: 32;  Resol:  9
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Convolution2D(8, 3, activation='relu'))                           #Receptive Field: 18;   Input Channels:  8;  Resol:  7
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Convolution2D(28, 3, activation='relu'))                           #Receptive Field: 20;   Input Channels: 8;  Resol:  5
model.add(BatchNormalization())
model.add(Dropout(0.2))

#Final Layers
model.add(Convolution2D(10, 3, activation='relu'))                              #Receptive Field: 24;   Input Channels: 28;  Resol:  3
model.add(Convolution2D(10, 3))                                                 #Receptive Field: 28;   Input Channels: 10;  Resol:  1
model.add(Flatten())
model.add(Activation('softmax'))

#MODEL ARCHITECTURE SUMMARY
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 8)         80
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 26, 26, 8)         32
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 26, 26, 8)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 8)         584
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 24, 24, 8)         32
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 24, 24, 8)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 22, 22, 28)        2044
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 22, 22, 28)        112
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 22, 22, 28)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 22, 22, 32)        928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 11, 11, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 9, 9, 8)           2312
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 9, 9, 8)           32
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 9, 9, 8)           0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 7, 7, 8)           584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 7, 7, 8)           32
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 7, 7, 8)           0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 5, 5, 28)          2044
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 5, 5, 28)          112
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 5, 5, 28)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 3, 3, 10)          2530
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 1, 1, 10)          910
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_1 (Activation)    (None, 10)                0
# =================================================================
# Total params: 12,368
# Trainable params: 12,192
# Non-trainable params: 176
# _________________________________________________________________

# %% [markdown]
# ###Provide parameters on which the model will train

# %%
model.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

# %% [markdown]
# ###Start training the model, save the model with best val accuracy

# %%
checkpointfilepath = "eva_assignment4_iteration3b_dpout20.hdf5"
checkpoint = ModelCheckpoint(checkpointfilepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]
model.fit(X_train, Y_train, batch_size=128, epochs=30, verbose=1, validation_data=(X_test, Y_test), callbacks=callbacks_list)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/30
# 60000/60000 [==============================] - 9s 147us/step - loss: 0.5907 - acc: 0.8051 - val_loss: 0.1997 - val_acc: 0.9352
#
# Epoch 00001: val_acc improved from -inf to 0.93520, saving model to eva_assignment4_iteration3b_dpout20.hdf5
# Epoch 2/30
# 60000/60000 [==============================] - 6s 104us/step - loss: 0.1491 - acc: 0.9532 - val_loss: 0.1136 - val_acc: 0.9641
#
# Epoch 00002: val_acc improved from 0.93520 to 0.96410, saving model to eva_assignment4_iteration3b_dpout20.hdf5
# Epoch 3/30
# 60000/60000 [==============================] - 6s 104us/step - loss: 0.1087 - acc: 0.9658 - val_loss: 0.0925 - val_acc: 0.9710
#
# Epoch 00003: val_acc improved from 0.96410 to 0.97100, saving model to eva_assignment4_iteration3b_dpout20.hdf5
# Epoch 4/30
# 60000/60000 [==============================] - 6s 104us/step - loss: 0.0878 - acc: 0.9729 - val_loss: 0.0714 - val_acc: 0.9779
#
# Epoch 00004: val_acc improved from 0.97100 to 0.97790, saving model to eva_assignment4_iteration3b_dpout20.hdf5
# Epoch 5/30
# 60000/60000 [==============================] - 6s 104us/step - loss: 0.0761 - acc: 0.9755 - val_loss: 0.0587 - val_acc: 0.9821
#
# Epoch 00005: val_acc improved from 0.97790 to 0.98210, saving model to eva_assignment4_iteration3b_dpout20.hdf5
# Epoch 6/30
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.0695 - acc: 0.9784 - val_loss: 0.0784 - val_acc: 0.9768
#
# Epoch 00006: val_acc did not improve from 0.98210
# Epoch 7/30
# 60000/60000 [==============================] - 7s 113us/step - loss: 0.0651 - acc: 0.9794 - val_loss: 0.0513 - val_acc: 0.9845
#
# Epoch 00007: val_acc improved from 0.98210 to 0.98450, saving model to eva_assignment4_iteration3b_dpout20.hdf5
# Epoch 8/30
# 60000/60000 [==============================] - 6s 104us/step - loss: 0.0609 - acc: 0.9810 - val_loss: 0.0602 - val_acc: 0.9825
#
# Epoch 00008: val_acc did not improve from 0.98450
# Epoch 9/30
# 60000/60000 [==============================] - 6s 104us/step - loss: 0.0571 - acc: 0.9818 - val_loss: 0.0463 - val_acc: 0.9865
#
# Epoch 00009: val_acc improved from 0.98450 to 0.98650, saving model to eva_assignment4_iteration3b_dpout20.hdf5
# Epoch 10/30
# 60000/60000 [==============================] - 6s 104us/step - loss: 0.0558 - acc: 0.9819 - val_loss: 0.0606 - val_acc: 0.9809
#
# Epoch 00010: val_acc did not improve from 0.98650
# Epoch 11/30
# 60000/60000 [==============================] - 6s 104us/step - loss: 0.0515 - acc: 0.9836 - val_loss: 0.0560 - val_acc: 0.9818
#
# Epoch 00011: val_acc did not improve from 0.98650
# Epoch 12/30
# 60000/60000 [==============================] - 6s 104us/step - loss: 0.0489 - acc: 0.9847 - val_loss: 0.0475 - val_acc: 0.9859
#
# Epoch 00012: val_acc did not improve from 0.98650
# Epoch 13/30
# 60000/60000 [==============================] - 6s 105us/step - loss: 0.0481 - acc: 0.9847 - val_loss: 0.0483 - val_acc: 0.9839
#
# Epoch 00013: val_acc did not improve from 0.98650
# Epoch 14/30
# 60000/60000 [==============================] - 6s 105us/step - loss: 0.0486 - acc: 0.9850 - val_loss: 0.0391 - val_acc: 0.9881
#
# Epoch 00014: val_acc improved from 0.98650 to 0.98810, saving model to eva_assignment4_iteration3b_dpout20.hdf5
# Epoch 15/30
# 60000/60000 [==============================] - 6s 104us/step - loss: 0.0455 - acc: 0.9856 - val_loss: 0.0361 - val_acc: 0.9882
#
# Epoch 00015: val_acc improved from 0.98810 to 0.98820, saving model to eva_assignment4_iteration3b_dpout20.hdf5
# Epoch 16/30
# 60000/60000 [==============================] - 6s 105us/step - loss: 0.0444 - acc: 0.9859 - val_loss: 0.0429 - val_acc: 0.9880
#
# Epoch 00016: val_acc did not improve from 0.98820
# Epoch 17/30
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.0438 - acc: 0.9863 - val_loss: 0.0338 - val_acc: 0.9901
#
# Epoch 00017: val_acc improved from 0.98820 to 0.99010, saving model to eva_assignment4_iteration3b_dpout20.hdf5
# Epoch 18/30
# 60000/60000 [==============================] - 7s 119us/step - loss: 0.0417 - acc: 0.9870 - val_loss: 0.0283 - val_acc: 0.9915
#
# Epoch 00018: val_acc improved from 0.99010 to 0.99150, saving model to eva_assignment4_iteration3b_dpout20.hdf5
# Epoch 19/30
# 60000/60000 [==============================] - 7s 116us/step - loss: 0.0428 - acc: 0.9864 - val_loss: 0.0348 - val_acc: 0.9887
#
# Epoch 00019: val_acc did not improve from 0.99150
# Epoch 20/30
# 60000/60000 [==============================] - 6s 107us/step - loss: 0.0411 - acc: 0.9872 - val_loss: 0.0332 - val_acc: 0.9901
#
# Epoch 00020: val_acc did not improve from 0.99150
# Epoch 21/30
# 60000/60000 [==============================] - 6s 105us/step - loss: 0.0390 - acc: 0.9880 - val_loss: 0.0286 - val_acc: 0.9910
#
# Epoch 00021: val_acc did not improve from 0.99150
# Epoch 22/30
# 60000/60000 [==============================] - 6s 105us/step - loss: 0.0390 - acc: 0.9874 - val_loss: 0.0307 - val_acc: 0.9908
#
# Epoch 00022: val_acc did not improve from 0.99150
# Epoch 23/30
# 60000/60000 [==============================] - 6s 105us/step - loss: 0.0380 - acc: 0.9884 - val_loss: 0.0284 - val_acc: 0.9915
#
# Epoch 00023: val_acc did not improve from 0.99150
# Epoch 24/30
# 60000/60000 [==============================] - 6s 104us/step - loss: 0.0376 - acc: 0.9882 - val_loss: 0.0281 - val_acc: 0.9924
#
# Epoch 00024: val_acc improved from 0.99150 to 0.99240, saving model to eva_assignment4_iteration3b_dpout20.hdf5
# Epoch 25/30
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.0356 - acc: 0.9890 - val_loss: 0.0239 - val_acc: 0.9917
#
# Epoch 00025: val_acc did not improve from 0.99240
# Epoch 26/30
# 60000/60000 [==============================] - 6s 105us/step - loss: 0.0368 - acc: 0.9884 - val_loss: 0.0234 - val_acc: 0.9930
#
# Epoch 00026: val_acc improved from 0.99240 to 0.99300, saving model to eva_assignment4_iteration3b_dpout20.hdf5
# Epoch 27/30
# 60000/60000 [==============================] - 7s 113us/step - loss: 0.0356 - acc: 0.9890 - val_loss: 0.0290 - val_acc: 0.9917
#
# Epoch 00027: val_acc did not improve from 0.99300
# Epoch 28/30
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.0352 - acc: 0.9885 - val_loss: 0.0262 - val_acc: 0.9922
#
# Epoch 00028: val_acc did not improve from 0.99300
# Epoch 29/30
# 60000/60000 [==============================] - 6s 105us/step - loss: 0.0348 - acc: 0.9889 - val_loss: 0.0267 - val_acc: 0.9914
#
# Epoch 00029: val_acc did not improve from 0.99300
# Epoch 30/30
# 60000/60000 [==============================] - 6s 105us/step - loss: 0.0363 - acc: 0.9882 - val_loss: 0.0284 - val_acc: 0.9914
#
# Epoch 00030: val_acc did not improve from 0.99300

# %% [markdown]
# ###Check model accuracy

# %%
model.load_weights(checkpointfilepath)
score = model.evaluate(X_test, Y_test, verbose=0)
print(score)
# Out:
# [0.02340591181264608, 0.993]

# %%
#CHECK A FEW MISCLASSIFIED IMAGES:
y_pred = model.predict(X_test)
y_pred.shape
# Out:
# (10000, 10)

# %% [markdown]
# ###Visualize what the filters in a particular layer extract

# %%
layer_dict = dict([(layer.name, layer) for layer in model.layers])

import numpy as np
from matplotlib import pyplot as plt
from keras import backend as K
# %matplotlib inline
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    #x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

def vis_img_in_filter(img = np.array(X_train[2]).reshape((1, 28, 28, 1)).astype(np.float64), 
                      layer_name = 'conv2d_4'):
    layer_output = layer_dict[layer_name].output
    img_ascs = list()
    for filter_index in range(layer_output.shape[3]):
        # build a loss function that maximizes the activation
        # of the nth filter of the layer considered
        loss = K.mean(layer_output[:, :, :, filter_index])

        # compute the gradient of the input picture wrt this loss
        grads = K.gradients(loss, model.input)[0]

        # normalization trick: we normalize the gradient
        grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

        # this function returns the loss and grads given the input picture
        iterate = K.function([model.input], [loss, grads])

        # step size for gradient ascent
        step = 5.

        img_asc = np.array(img)
        # run gradient ascent for 20 steps
        for i in range(20):
            loss_value, grads_value = iterate([img_asc])
            img_asc += grads_value * step

        img_asc = img_asc[0]
        img_ascs.append(deprocess_image(img_asc).reshape((28, 28)))
        
    if layer_output.shape[3] >= 35:
        plot_x, plot_y = 6, 6
    elif layer_output.shape[3] >= 23:
        plot_x, plot_y = 4, 6
    elif layer_output.shape[3] >= 11:
        plot_x, plot_y = 2, 6
    else:
        plot_x, plot_y = 1, 2
    fig, ax = plt.subplots(plot_x, plot_y, figsize = (12, 12))
    ax[0, 0].imshow(img.reshape((28, 28)), cmap = 'gray')
    ax[0, 0].set_title('Input image')
    fig.suptitle('Input image and %s filters' % (layer_name,))
    fig.tight_layout(pad = 0.3, rect = [0, 0, 0.9, 0.9])
    for (x, y) in [(i, j) for i in range(plot_x) for j in range(plot_y)]:
        if x == 0 and y == 0:
            continue
        ax[x, y].imshow(img_ascs[x * plot_y + y - 1], cmap = 'gray')
        ax[x, y].set_title('filter %d' % (x * plot_y + y - 1))

vis_img_in_filter()

# %%
#CHECK A FEW MISCLASSIFIED IMAGES:
